# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
data=pd.read_csv("bluebook-for-bulldozers/TrainAndValid/TrainAndValid.csv")
# Out:
# C:\Users\Qadri laptop\AppData\Local\Temp\ipykernel_9828\649617236.py:1: DtypeWarning: Columns (13,39,40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("bluebook-for-bulldozers/TrainAndValid/TrainAndValid.csv")

# %%
data.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    265194
# UsageBand                   339028
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# Transmission                224691
# ...

# %%
ax=plt.subplot()
ax.scatter(data['SalePrice'][:1000],data['saledate'][:1000])

# %%
data.SalePrice.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
Data=pd.read_csv("bluebook-for-bulldozers/TrainAndValid/TrainAndValid.csv",parse_dates=['saledate'])
Data
# Out:
# C:\Users\Qadri laptop\AppData\Local\Temp\ipykernel_9828\2241377936.py:1: DtypeWarning: Columns (13,39,40,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   Data=pd.read_csv("bluebook-for-bulldozers/TrainAndValid/TrainAndValid.csv",parse_dates=['saledate'])
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 0       1139246    66000.0     999089     3157         121           3.0
# 1       1139248    57000.0     117657       77         121           3.0
# 2       1139249    10000.0     434808     7009         121           3.0
# 3       1139251    38500.0    1026470      332         121           3.0
# 4       1139253    11000.0    1057373    17311         121           3.0
# ...         ...        ...        ...      ...         ...           ...
# 412693  6333344    10000.0    1919201    21435         149           2.0
# 412694  6333345    10500.0    1882122    21436         149           2.0
# ...

# %%
ax=plt.subplot()
ax.scatter(Data['saledate'][:1000],Data['SalePrice'][:1000])

# %%
Data.sort_values(by=['saledate'],inplace=True,ascending=True)
Data.saledate.head()
# Out:
# 205615   1989-01-17
# 128751   1989-01-31
# 67974    1989-01-31
# 274835   1989-01-31
# 141296   1989-01-31
# Name: saledate, dtype: datetime64[ns]

# %%
Data_Temp=Data.copy()
Data_Temp.head().T
# Out:
#                                                                      205615  \
# SalesID                                                             1646770
# SalePrice                                                            9500.0
# MachineID                                                           1126363
# ModelID                                                                8434
# datasource                                                              132
# auctioneerID                                                           18.0
# YearMade                                                               1974
# MachineHoursCurrentMeter                                                NaN
# UsageBand                                                               NaN
# saledate                                                1989-01-17 00:00:00
# fiModelDesc                                                            TD20
# ...

# %%
Data_Temp.saledate.dt.year
# Out:
# 205615    1989
# 128751    1989
# 67974     1989
# 274835    1989
# 141296    1989
#           ...
# 409202    2012
# 411890    2012
# 408976    2012
# 409297    2012
# 409203    2012
# Name: saledate, Length: 412698, dtype: int32

# %%
Data_Temp['saleYear']=Data_Temp.saledate.dt.year
Data_Temp['saleMonth']=Data_Temp.saledate.dt.month
Data_Temp['saleDay']=Data_Temp.saledate.dt.day
Data_Temp['saledayofweek']=Data_Temp.saledate.dt.dayofweek
Data_Temp['saledayofYear']=Data_Temp.saledate.dt.dayofyear

# %%
Data_Temp.head().T
# Out:
#                                                                      205615  \
# SalesID                                                             1646770
# SalePrice                                                            9500.0
# MachineID                                                           1126363
# ModelID                                                                8434
# datasource                                                              132
# auctioneerID                                                           18.0
# YearMade                                                               1974
# MachineHoursCurrentMeter                                                NaN
# UsageBand                                                               NaN
# saledate                                                1989-01-17 00:00:00
# fiModelDesc                                                            TD20
# ...

# %%
Data_Temp.drop('saledate',axis=1,inplace=True)

# %%
Data_Temp.state.value_counts()
# Out:
# state
# Florida           67320
# Texas             53110
# California        29761
# Washington        16222
# Georgia           14633
# Maryland          13322
# Mississippi       13240
# Ohio              12369
# Illinois          11540
# Colorado          11529
# New Jersey        11156
# North Carolina    10636
# Tennessee         10298
# Alabama           10292
# Pennsylvania      10234
# South Carolina     9951
# Arizona            9364
# New York           8639
# Connecticut        8276
# Minnesota          7885
# Missouri           7178
# Nevada             6932
# Louisiana          6627
# Kentucky           5351
# Maine              5096
# Indiana            4124
# Arkansas           3933
# New Mexico         3631
# Utah               3046
# Unspecified        2801
# Wisconsin          2745
# New Hampshire      2738
# Virginia           2353
# Idaho              2025
# Oregon             1911
# Michigan           1831
# Wyoming            1672
# Montana            1336
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_jobs=-1,random_state=42)

# %%
Data_Temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 412698 entries, 205615 to 409203
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   object
#  9   fiModelDesc               412698 non-null  object
#  10  fiBaseModel               412698 non-null  object
#  11  fiSecondaryDesc           271971 non-null  object
#  12  fiModelSeries             58667 non-null   object
# ...

# %%
from pandas.api.types import is_string_dtype
for label,content in Data_Temp.items():
    if is_string_dtype(content):
        print(label)
# Out:
# fiModelDesc
# fiBaseModel
# fiProductClassDesc
# state
# ProductGroup
# ProductGroupDesc

# %%
is_string_dtype('UsageBand')
# Out:
# False

# %%
for label,content in data_temp.items():
    if pd.api.types.is_string_dtype(content):
        Data_temp[label]=content.astype('category').cat.as_ordered

# %%
daaata=data_temp.copy()

# %%
Data_Temp.state.cat.codes.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[249], line 1
# ----> 1 Data_Temp.state.cat.codes.head()
#
# File ~\Desktop\Bull_Dozer_Project\env\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\Desktop\Bull_Dozer_Project\env\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
d=Data_temp.state.value_counts();
d
# Out:
# state
# <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.arrays.categorical.CategoricalAccessor object at 0x00000166E54A07A0>>    412698
# Name: count, dtype: int64

# %%
 Data_temp['state'].cat.categories
# Out:
# Index([<bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.arrays.categorical.CategoricalAccessor object at 0x00000166E54A07A0>>], dtype='object')

# %%
daaata
# Out:
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 205615  1646770     9500.0    1126363     8434         132          18.0
# 128751  1477524    10000.0    1078853     4103         132          99.0
# 67974   1344379    70000.0    1374638     3819         132          99.0
# 274835  1821514    14000.0    1194089    10150         132          99.0
# 141296  1505138    50000.0    1473654     4139         132          99.0
# ...         ...        ...        ...      ...         ...           ...
# 409202  6283634    35000.0    1930870     4701         149          99.0
# 411890  6312473    11000.0    1796787    17231         149          99.0
# 408976  6282337     7500.0    1928688    22072         149          99.0
# 409297  6283945    47000.0    1718212     4754         149          99.0
# 409203  6283635    34000.0    1869284     4701         149          99.0
#
#         YearMade  MachineHoursCurrentMeter UsageBand   saledate  ...  \
# ...

# %%
for label,content in Data_Temp.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            Data_Temp[label+'is_missing']=pd.isnull(content)
            Data_Temp[label]=content.fillna(content.median())

# %%
Data_Temp.isna().sum()
# Out:
# SalesID                                    0
# SalePrice                                  0
# MachineID                                  0
# ModelID                                    0
# datasource                                 0
# auctioneerID                               0
# YearMade                                   0
# MachineHoursCurrentMeter                   0
# UsageBand                             339028
# fiModelDesc                                0
# fiBaseModel                                0
# fiSecondaryDesc                       140727
# fiModelSeries                         354031
# fiModelDescriptor                     337882
# ProductSize                           216605
# fiProductClassDesc                         0
# state                                      0
# ProductGroup                               0
# ProductGroupDesc                           0
# Drive_System                          305611
# Enclosure                                334
# ...

# %%
Data_Temp.MachineHoursCurrentMeteris_missing.value_counts()
# Out:
# MachineHoursCurrentMeteris_missing
# True     265194
# False    147504
# Name: count, dtype: int64

# %%
len(Data_Temp)
# Out:
# 412698

# %%
pd.Categorical(Data_Temp['ProductSize']).codes
# Out:
# array([ 3, -1,  3, ..., -1,  3, -1], dtype=int8)

# %%
for label, content in Data_Temp.items():
    if not pd.api.types.is_numeric_dtype(content):
        print(label)
# Out:
# UsageBand
# fiModelDesc
# fiBaseModel
# fiSecondaryDesc
# fiModelSeries
# fiModelDescriptor
# ProductSize
# fiProductClassDesc
# state
# ProductGroup
# ProductGroupDesc
# Drive_System
# Enclosure
# Forks
# Pad_Type
# Ride_Control
# Stick
# Transmission
# Turbocharged
# Blade_Extension
# Blade_Width
# Enclosure_Type
# Engine_Horsepower
# Hydraulics
# Pushblock
# Ripper
# Scarifier
# Tip_Control
# Tire_Size
# Coupler
# Coupler_System
# Grouser_Tracks
# Hydraulics_Flow
# Track_Type
# Undercarriage_Pad_Width
# Stick_Length
# Thumb
# Pattern_Changer
# Grouser_Type
# Backhoe_Mounting
# Blade_Type
# Travel_Controls
# Differential_Type
# Steering_Controls

# %%
for label,content in Data_Temp.items():
    if not pd.api.types.is_numeric_dtype(content):
        Data_Temp[label+'missing']=pd.isnull(content)
        Data_Temp[label]=pd.Categorical(content).codes+1

# %%
Data_Temp.isna().sum()
# Out:
# SalesID                     0
# SalePrice                   0
# MachineID                   0
# ModelID                     0
# datasource                  0
#                            ..
# Backhoe_Mountingmissing     0
# Blade_Typemissing           0
# Travel_Controlsmissing      0
# Differential_Typemissing    0
# Steering_Controlsmissing    0
# Length: 103, dtype: int64

# %%
Data_Temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 412698 entries, 205615 to 409203
# Columns: 103 entries, SalesID to Steering_Controlsmissing
# dtypes: bool(46), float64(3), int16(5), int32(5), int64(5), int8(39)
# memory usage: 89.7 MB

# %%
Data_Temp.head().T
# Out:
#                            205615   128751   67974    274835   141296
# SalesID                   1646770  1477524  1344379  1821514  1505138
# SalePrice                  9500.0  10000.0  70000.0  14000.0  50000.0
# MachineID                 1126363  1078853  1374638  1194089  1473654
# ModelID                      8434     4103     3819    10150     4139
# datasource                    132      132      132      132      132
# ...                           ...      ...      ...      ...      ...
# Backhoe_Mountingmissing     False    False     True     True    False
# Blade_Typemissing           False    False     True     True    False
# Travel_Controlsmissing      False    False     True     True    False
# Differential_Typemissing     True     True    False    False     True
# Steering_Controlsmissing     True     True    False    False     True
#
# [103 rows x 5 columns]

# %%
# %%time
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_jobs=-1,random_state=42)
model.fit(Data_Temp.drop('SalePrice',axis=1),Data_Temp['SalePrice'])
# Out:
# CPU times: total: 41min 5s
# Wall time: 6min 27s
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
model.score(Data_Temp.drop('SalePrice',axis=1),Data_Temp['SalePrice'])
# Out:
# 0.9875928798398416

# %%
data_val=Data_Temp[Data_Temp.saleYear==2012]
data_train=Data_Temp[Data_Temp.saleYear!=2012]

# %%
X_train,Y_train=data_train.drop('SalePrice',axis=1),data_train['SalePrice']
X_valid,Y_valid=data_val.drop('SalePrice',axis=1),data_val['SalePrice']

# %%
X_train.shape,Y_train.shape,X_valid.shape,Y_valid.shape
# Out:
# ((401125, 102), (401125,), (11573, 102), (11573,))

# %%
from sklearn.metrics import mean_squared_log_error,mean_absolute_error,r2_score
def RMSLE(y_test,y_preds):
    return np.sqrt(mean_squared_log_error(y_test,y_preds))

# %%
def show_model(model):
    train_preds=model.predict(X_train)
    val_preds=model.predict(X_valid)
    score={'Training MAE':mean_absolute_error(Y_train,train_preds),
    'Valid MAE':mean_absolute_error(Y_valid,val_preds),
    'Training RMSLE':RMSLE(Y_train,train_preds),
    'Valid RMSLE':RMSLE(Y_Valid,val_preds),
    'Training R^2':r2_score(Y_train,train_preds),
    'Valid R^2':r2_score(Y_Valid,val_preds)}
    return score

# %%
# %%time
model=RandomForestRegressor(n_jobs=-1,random_state=42,max_samples=10000)
model.fit(X_train,Y_train)
# Out:
# CPU times: total: 1min 30s
# Wall time: 14.1 s
# RandomForestRegressor(max_samples=10000, n_jobs=-1, random_state=42)

# %%
show_model(model)
# Out:
# {'Training MAE': 5559.148208114678,
#  'Valid MAE': 7149.566775252742,
#  'Training RMSLE': 0.2574553976486982,
#  'Valid RMSLE': 0.29322873346215367,
#  'Training R^2': 0.8605666782378764,
#  'Valid R^2': 0.8334485200001668}

# %%
from sklearn.model_selection import RandomizedSearchCV
param_grid = {
    'n_estimators': np.arange(10, 100, 10),
    'max_depth': [None, 3, 5, 10],
    'min_samples_split': np.arange(2, 20, 2),
    'min_samples_leaf': np.arange(1, 20, 2),
    'max_features': ['sqrt', 'auto', 0.5, 1],
    'max_samples': [10000]
}
rs_model=RandomizedSearchCV(estimator=RandomForestRegressor(n_jobs=-1,random_state=42),
                                              param_distributions=param_grid, 
                                              n_iter=5,
                                              cv=5, verbose=2)
rs_model.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] END max_depth=5, max_features=0.5, max_samples=10000, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   1.8s
# [CV] END max_depth=5, max_features=0.5, max_samples=10000, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   1.7s
# [CV] END max_depth=5, max_features=0.5, max_samples=10000, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   1.7s
# [CV] END max_depth=5, max_features=0.5, max_samples=10000, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   1.7s
# [CV] END max_depth=5, max_features=0.5, max_samples=10000, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   1.6s
# [CV] END max_depth=None, max_features=sqrt, max_samples=10000, min_samples_leaf=17, min_samples_split=4, n_estimators=30; total time=   1.3s
# ...

# %%
show_model(rs_model)
# Out:
# {'Training MAE': 8679.173159488733,
#  'Valid MAE': 10370.51140560415,
#  'Training RMSLE': 0.38174824349729736,
#  'Valid RMSLE': 0.41315035592946314,
#  'Training R^2': 0.6971784144291837,
#  'Valid R^2': 0.6857274807907185}

# %%
print(rs_model.best_params_)
# Out:
# {'n_estimators': 30, 'min_samples_split': 4, 'min_samples_leaf': 17, 'max_samples': 10000, 'max_features': 'sqrt', 'max_depth': None}

# %%
 rs_model.best_estimator_
# Out:
# RandomForestRegressor(max_features='sqrt', max_samples=10000,
#                       min_samples_leaf=17, min_samples_split=4, n_estimators=30,
#                       n_jobs=-1, random_state=42)

# %%
from sklearn.model_selection import RandomizedSearchCV
param_grid = {
    'n_estimators': np.arange(10, 100, 10),
    'max_depth': [None, 3, 5, 10],
    'min_samples_split': np.arange(2, 20, 2),
    'min_samples_leaf': np.arange(1, 20, 2),
    'max_features': ['sqrt', 'auto', 0.5, 1],
    'max_samples': [10000]
}
rs_model=RandomizedSearchCV(estimator=RandomForestRegressor(n_jobs=-1,random_state=42),
                                              param_distributions=param_grid, 
                                              n_iter=100,
                                              cv=5, verbose=True)
rs_model.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# C:\Users\Qadri laptop\Desktop\Bull_Dozer_Project\env\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 125 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 125 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Qadri laptop\Desktop\Bull_Dozer_Project\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Qadri laptop\Desktop\Bull_Dozer_Project\env\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
# ...

# %%
print(rs_model.best_params_)
# Out:
# {'n_estimators': 30, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_samples': 10000, 'max_features': 0.5, 'max_depth': None}

# %%
show_model(rs_model)
# Out:
# {'Training MAE': 6098.0748653097835,
#  'Valid MAE': 7673.672860758402,
#  'Training RMSLE': 0.279623912971842,
#  'Valid RMSLE': 0.31071249770264586,
#  'Training R^2': 0.8331119988717903,
#  'Valid R^2': 0.8056559507875327}

# %%
ideal_model=RandomForestRegressor(n_estimators=30 , 
min_samples_split= 10, 
min_samples_leaf= 7,
max_samples= None ,
max_features= 0.5,
max_depth= None)

# %%
# %%time
ideal_model.fit(X_train,Y_train)
# Out:
# CPU times: total: 3min 18s
# Wall time: 3min 35s
# RandomForestRegressor(max_features=0.5, min_samples_leaf=7,
#                       min_samples_split=10, n_estimators=30)

# %%
show_model(ideal_model)
# Out:
# {'Training MAE': 3537.68494581493,
#  'Valid MAE': 5978.112705950395,
#  'Training RMSLE': 0.17160727686003,
#  'Valid RMSLE': 0.24589857362669426,
#  'Training R^2': 0.9395562339704338,
#  'Valid R^2': 0.878748921538501}

# %%
data_test=pd.read_csv("bluebook-for-bulldozers/Test.csv",parse_dates=['saledate'])

# %%
data_test['saleYear']=data_test.saledate.dt.year
data_test['saleMonth']=data_test.saledate.dt.month
data_test['saleDay']=data_test.saledate.dt.day
data_test['saledayofweek']=data_test.saledate.dt.dayofweek
data_test['saledayofYear']=data_test.saledate.dt.dayofyear
data_test.drop('saledate',axis=1,inplace=True)

# %%
data_test
# Out:
#        SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0      1227829    1006309     3168         121             3      1999
# 1      1227844    1022817     7271         121             3      1000
# 2      1227847    1031560    22805         121             3      2004
# 3      1227848      56204     1269         121             3      2006
# 4      1227863    1053887    22312         121             3      2005
# ...        ...        ...      ...         ...           ...       ...
# 12452  6643171    2558317    21450         149             2      2008
# 12453  6643173    2558332    21434         149             2      2005
# 12454  6643184    2558342    21437         149             2      1000
# 12455  6643186    2558343    21437         149             2      2006
# 12456  6643196    2558346    21446         149             2      2008
#
#        MachineHoursCurrentMeter UsageBand fiModelDesc fiBaseModel  ...  \
# ...

# %%
pd.Categorical(data_test['ProductSize']).codes
# Out:
# array([-1,  3,  2, ...,  4,  4,  4], dtype=int8)

# %%
data_test.isna().sum()
# Out:
# SalesID                         0
# MachineID                       0
# ModelID                         0
# datasource                      0
# auctioneerID                    0
# YearMade                        0
# MachineHoursCurrentMeter    10328
# UsageBand                   10623
# fiModelDesc                     0
# fiBaseModel                     0
# fiSecondaryDesc              3975
# fiModelSeries               10451
# fiModelDescriptor            9433
# ProductSize                  6409
# fiProductClassDesc              0
# state                           0
# ProductGroup                    0
# ProductGroupDesc                0
# Drive_System                 9698
# Enclosure                       2
# Forks                        6149
# Pad_Type                    10349
# Ride_Control                 8216
# Stick                       10349
# Transmission                 7639
# Turbocharged                10349
# Blade_Extension             11806
# ...

# %%
for label,content in data_test.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            data_test[label+'is_missing']=pd.isnull(content)
            data_test[label]=content.fillna(content.median())

# %%
data_test.isna().sum()
# Out:
# SalesID                                   0
# MachineID                                 0
# ModelID                                   0
# datasource                                0
# auctioneerID                              0
# YearMade                                  0
# MachineHoursCurrentMeter                  0
# UsageBand                             10623
# fiModelDesc                               0
# fiBaseModel                               0
# fiSecondaryDesc                        3975
# fiModelSeries                         10451
# fiModelDescriptor                      9433
# ProductSize                            6409
# fiProductClassDesc                        0
# state                                     0
# ProductGroup                              0
# ProductGroupDesc                          0
# Drive_System                           9698
# Enclosure                                 2
# Forks                                  6149
# ...

# %%
for label,content in data_test.items():
    if not pd.api.types.is_numeric_dtype(content):
        data_test[label+'missing']=pd.isnull(content)
        data_test[label]=pd.Categorical(content).codes+1

# %%
data_test.isna().sum()
# Out:
# SalesID                     0
# MachineID                   0
# ModelID                     0
# datasource                  0
# auctioneerID                0
#                            ..
# Backhoe_Mountingmissing     0
# Blade_Typemissing           0
# Travel_Controlsmissing      0
# Differential_Typemissing    0
# Steering_Controlsmissing    0
# Length: 101, dtype: int64

# %%
data_test.columns
# Out:
# Index(['SalesID', 'MachineID', 'ModelID', 'datasource', 'auctioneerID',
#        'YearMade', 'MachineHoursCurrentMeter', 'UsageBand', 'fiModelDesc',
#        'fiBaseModel',
#        ...
#        'Undercarriage_Pad_Widthmissing', 'Stick_Lengthmissing', 'Thumbmissing',
#        'Pattern_Changermissing', 'Grouser_Typemissing',
#        'Backhoe_Mountingmissing', 'Blade_Typemissing',
#        'Travel_Controlsmissing', 'Differential_Typemissing',
#        'Steering_Controlsmissing'],
#       dtype='object', length=101)

# %%
data_temp.columns
# Out:
# Index(['SalesID', 'SalePrice', 'MachineID', 'ModelID', 'datasource',
#        'auctioneerID', 'YearMade', 'MachineHoursCurrentMeter', 'UsageBand',
#        'saledate',
#        ...
#        'Undercarriage_Pad_Widthmissing', 'Stick_Lengthmissing', 'Thumbmissing',
#        'Pattern_Changermissing', 'Grouser_Typemissing',
#        'Backhoe_Mountingmissing', 'Blade_Typemissing',
#        'Travel_Controlsmissing', 'Differential_Typemissing',
#        'Steering_Controlsmissing'],
#       dtype='object', length=105)

# %%
X_train.head()
# Out:
#         SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 205615  1646770    1126363     8434         132          18.0      1974
# 128751  1477524    1078853     4103         132          99.0      1972
# 67974   1344379    1374638     3819         132          99.0      1982
# 274835  1821514    1194089    10150         132          99.0      1980
# 141296  1505138    1473654     4139         132          99.0      1978
#
#         MachineHoursCurrentMeter  UsageBand  saledate  fiModelDesc  ...  \
# 205615                       0.0          0         1         4593  ...
# 128751                       0.0          0         2         2169  ...
# 67974                        0.0          0         2         1740  ...
# 274835                       0.0          0         2         1820  ...
# 141296                       0.0          0         2         2348  ...
#
#         Undercarriage_Pad_Widthmissing  Stick_Lengthmissing  Thumbmissing  \
# ...

# %%
data_test.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1227829    1006309     3168         121             3      1999
# 1  1227844    1022817     7271         121             3      1000
# 2  1227847    1031560    22805         121             3      2004
# 3  1227848      56204     1269         121             3      2006
# 4  1227863    1053887    22312         121             3      2005
#
#    MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...  \
# 0                    3688.0          2          499          180  ...
# 1                   28555.0          1          831          292  ...
# 2                    6038.0          3         1177          404  ...
# 3                    8940.0          1          287          113  ...
# 4                    2286.0          2          566          196  ...
#
#    Undercarriage_Pad_Widthmissing  Stick_Lengthmissing  Thumbmissing  \
# ...

# %%
set(Data_Temp.columns)-set(data_test.columns)
# Out:
# set()

# %%
Data_Temp=Data_Temp.drop('SalePrice',axis=1)

# %%
data_test['auctioneerIDis_missing']=False
data_test.head().T
# Out:
#                                 0        1        2        3        4
# SalesID                   1227829  1227844  1227847  1227848  1227863
# MachineID                 1006309  1022817  1031560    56204  1053887
# ModelID                      3168     7271    22805     1269    22312
# datasource                    121      121      121      121      121
# auctioneerID                    3        3        3        3        3
# ...                           ...      ...      ...      ...      ...
# Blade_Typemissing            True     True     True     True    False
# Travel_Controlsmissing       True     True     True     True    False
# Differential_Typemissing     True    False     True     True     True
# Steering_Controlsmissing     True    False     True     True     True
# auctioneerIDis_missing      False    False    False    False    False
#
# [102 rows x 5 columns]

# %%
test_preds=ideal_model.predict(data_test)

# %%
feature_names = X_train.columns

# %%
data_test = data_test[feature_names]

# %%
test_preds
# Out:
# array([18841.60928954, 15854.29512266, 46975.2892543 , ...,
#        12649.21279308, 18225.82778307, 27234.56853552])

# %%
df_preds=pd.DataFrame()
df_preds['SalesID']=data_test['SalesID']
df_preds['SalesPrice']=test_preds
df_preds
# Out:
#        SalesID    SalesPrice
# 0      1227829  18841.609290
# 1      1227844  15854.295123
# 2      1227847  46975.289254
# 3      1227848  55183.490153
# 4      1227863  56155.847051
# ...        ...           ...
# 12452  6643171  43316.043573
# 12453  6643173  11940.776596
# 12454  6643184  12649.212793
# 12455  6643186  18225.827783
# 12456  6643196  27234.568536
#
# [12457 rows x 2 columns]

# %%
df_preds.to_csv('test_preds.csv',index=False)
